# %%
import nltk
import urllib.request
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
res = urllib.request.urlopen("https://www.electronics-lab.com/")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-17-07c3a6c42f85> in <module>
# ----> 1 res = urllib.request.urlopen("https://www.travelocity.com/")
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests

# %%
html = res.read()

# %%
# html

# %%
soup = BeautifulSoup(html,"html5lib")

# %%
text = soup.get_text()

# %%
# text

# %%
tokens = word_tokenize(text,"spanish")

# %%
tokens = [word.lower() for word in tokens if word.isalpha()]

# %%
tokens
# Out:
# []

# %%
tokens = [word.lower() for word in tokens if word.isalpha()]

# %%
def frecuenciaPalabras(tokens):
    freq = nltk.FreqDist(tokens)
    for palabra,valor in freq.items():
        print(f"{palabra}: {valor}")
    return freq

# %%
def vizualizarTokens(tokens):
    tokens.plot(30,cumulative=False)

# %%
freq = frecuenciaPalabras(tokens)

# %%
vizualizarTokens(freq)

# %%
 Tokens_limpios = tokens[:]

for token in tokens:
    if token in stopwords.words("spanish"):
        Tokens_limpios.remove(token)

# %%
frecuencia_limpia = frecuenciaPalabras(Tokens_limpios)
# Out:
# turismo: 19
# online: 4
# viajes: 1
# destinos: 6
# paises: 1
# ciudades: 1
# hoteles: 3
# consejos: 7
# function: 2
# i: 8
# s: 1
# g: 2
# r: 6
# m: 2
# googleanalyticsobject: 1
# arguments: 1
# new: 1
# date: 1
# window: 1
# document: 1
# script: 1
# https: 1
# ga: 5
# create: 1
# cookiedomain: 1
# auto: 2
# require: 1
# displayfeatures: 1
# set: 1
# anonymizeip: 1
# true: 3
# send: 1
# pageview: 1
# basepath: 1
# pathprefix: 1
# ajaxpagestate: 1
# theme: 1
# sbn: 1
# js: 1
# public: 1
# css: 1
# lazyloader: 1
# throttle: 1
# offset: 1
# debounce: 1
# unload: 1
# icon: 1
# offsetx: 1
# offsety: 1
# googleanalytics: 1
# trackoutbound: 1
# trackmailto: 1
# trackdownload: 1
# trackdownloadextensions: 1
# ie: 1
# urlisajaxtrusted: 1
# bootstrap: 1
# anchorsfix: 1
# anchorssmoothscrolling: 1
# formhaserror: 1
# popoverenabled: 1
# popoveroptions: 1
# animation: 2
# html: 2
# placement: 2
# right: 1
# selector: 2
# trigger: 2
# click: 1
# triggerautoclose: 1
# title: 1
# content: 1
# delay: 2
# container: 2
# body: 2
# tooltipenabled: 1
# tooltipoptions: 1
# left: 1
# hover: 1
# focus: 1
# article: 1
# f: 2
# u: 2
# if: 2
# typeof: 1
# navegacion: 1
# consejosdestinosturismoalojamientoentretenimientomás: 1
# ultimotransporteeventos: 1
# promocionespaíses: 1
# regiones: 1
# síguenos: 1
# adsbygoogle: 2
# lugares: 2
# atractivos: 2
# viterbola: 1
# provincia: 1
# viterbo: 1
# ubicada: 1
# región: 1
# lazio: 1
# ocasión: 1
# sido: 1
# excluida: 1
# circuito: 1
# turístico: 2
# pesar: 2
# joyas: 1
# arquitectónicas: 1
# históricas: 1
# maneras: 2
# ser: 2
# mejor: 2
# viajero: 2
# luego: 2
# confinamiento: 1
# parques: 5
# atracciones: 4
# españa: 2
# jardines: 1
# turísticos: 3
# inteligentes: 1
# estrategias: 2
# redes: 3
# sociales: 3
# negocio: 3
# destinosparques: 1
# españaturismo: 2
# jardinesqué: 2
# inteligentesdestinos: 2
# turismocontribuye: 1
# casadestinos: 3
# informacion: 3
# turismoviajes: 1
# aprendizaje: 2
# jamaicadestinos: 2
# hotelessevilla: 1
# ciudad: 1
# romántica: 1
# españaciudades: 1
# toursla: 1
# alhambra: 2
# granadadestinos: 2
# sitios: 3
# historicos: 3
# monumentoslas: 1
# pirámides: 1
# gizadestinos: 1
# confinamientoturismo: 1
# consejosparques: 1
# turísticoturismo: 2
# consejoscontribuye: 2
# turismoestrategias: 2
# digitales: 2
# reinventar: 2
# sector: 2
# turísticoinformacion: 2
# salud: 2
# turismohoteles: 1
# deberías: 1
# visitar: 1
# menos: 1
# vez: 1
# vidaturismo: 1
# alojamiento: 3
# entretenimientolos: 1
# viterbociudades: 1
# entretenimientola: 1
# monumentos: 1
# informaciónestrategias: 1
# cómo: 1
# encontrar: 1
# baño: 1
# viajeturismo: 1
# consejosclaves: 1
# pasar: 2
# control: 2
# aeropuertoturismo: 2
# aeropuertostrenes: 2
# recorrer: 2
# argentinainformacion: 2
# trenes: 2
# turismoel: 1
# regenerativoinformacion: 1
# rural: 1
# transporteviajes: 1
# hoteleshoteles: 1
# sustentables: 1
# latinoaméricaturismo: 1
# hotelesclaves: 1
# eventos: 2
# especialespaíses: 1
# celebran: 1
# día: 1
# muertospaises: 1
# eventospaíses: 1
# latinos: 1
# nominados: 1
# world: 1
# travel: 1
# awards: 1
# llamar: 1
# casa: 1
# viaje: 1
# normas: 1
# existentes: 1
# ecológicos: 1
# patrimonios: 1
# humanidad: 1
# américa: 1
# latina: 1
# horarios: 1
# comerciales: 1
# tiendas: 1
# típicas: 1
# bariloche: 1
# libro: 1
# recetas: 1
# mitos: 2
# falsos: 2
# azúcar: 1
# pimienta: 1
# tipos: 1
# usos: 2
# diez: 1
# cortes: 1
# atún: 1
# culinariossanar: 1
# misofobia: 1
# obsesivo: 1
# miedo: 1
# gérmenes: 1
# albinismo: 1
# protege: 1
# ojos: 1
# coronavirus: 1
# bello: 1
# magazine: 1
# vida: 1
# obra: 1
# ennio: 1
# morricone: 1
# origen: 1
# días: 1
# semana: 1
# curiosidades: 1
# bibliabellezas: 1
# latinas: 1
# magia: 1
# blanca: 1
# rituales: 1
# amor: 1
# hombres: 1
# dejan: 1
# mujeres: 1
# remedios: 1
# caseros: 1
# congestión: 1
# nasal: 1
# bebés: 1
# coyuntura: 1
# economica: 1
# recesiones: 1
# últimos: 1
# años: 1
# países: 1
# cuyas: 1
# economías: 1
# crecerán: 1
# pandemia: 1
# datos: 1
# grafican: 1
# racismo: 1
# unidosrincon: 1
# peruano: 1
# empresas: 1
# quejas: 1
# compras: 1
# línea: 1
# aspectos: 1
# positivos: 1
# gobierno: 1
# juan: 1
# velasco: 1
# alvarado: 1
# machu: 1
# picchu: 1
# acercaprivacidadtérminoscontactarturismo: 1
# derechos: 1
# reservados: 1
# flush: 1

# %%
vizualizarTokens(frecuencia_limpia)
